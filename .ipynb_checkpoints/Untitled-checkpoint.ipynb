# %%
count  = 0
total = 0
max_value = None 
min_value = None
while True:
    line= input("Enter a Number")
    if line.lower() == 'Done':
        break
    try:
        number = float(line)
    except:
        print('Invalid Input')
        continue
    count += 1
    total += number 
    if max_value is None or number > max_value:
        max_value = number
    if min_value is None or number < min_value:
        min_value = number
print(count, total, max_value, min_value)
# Out:
# Enter a Number 45
# Enter a Number 34
# Enter a Number 12
# Enter a Number 67
# Enter a Number 89
# Enter a Number gnfng
# Invalid Input
# Enter a Number 34
# Enter a Number DONE
# Invalid Input
# Enter a Number done
# Invalid Input

# %%
total = 0
count = 0

while True:
    line = input("Enter a number (or 'done' to finish): ")

    if line.lower() == "done":
        break
    try:
        number = float(line)
    except ValueError:
        print("Error: Please enter a numeric value or 'done'. ")
        continue

    total += number
    count += 1

 
    if    count > 0:
        average = total / count 
        print("Total:", total)
        print("Count:", count)
        print("Average", average)
    else:
        print("No numbers were ebterd.")
# Out:
# Enter a number (or 'done' to finish):  34
# Total: 34.0
# Count: 1
# Average 34.0

# %%
count = 0
total = 0
max_value = None
min_value = None
while True:
    line = input("Enter a Number")
    if line.lower() == 'done':
        break
    try:
        number = float(line)
    except:
        print("Invalid Input")
        continue
    count += 1
    total += number
    if max_value is None or number > max_value:
        max_value = number       
    if min_value is None or number < min_value:
        min_value = number
        
print("count:", count)
print("total:", total)
print("max_value", max_value)
print("min_value", min_value)
# Out:
# Enter a Number 2.33
# Enter a Number 4.455577
# Enter a Number 7.9035
# Enter a Number JDJDS\
# Invalid Input
# Enter a Number 3.890
# Enter a Number DONER
# Invalid Input
# Enter a Number DONE
# count: 4
# total: 18.579077
# max_value 7.9035
# min_value 2.33

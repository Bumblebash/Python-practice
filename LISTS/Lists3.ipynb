# %%
### 5/06/2026

# %% [markdown]
# ### Lists and Strings

# %%
s = 'spam'
t = list(s)
print(t)
# Out:
# ['s', 'p', 'a', 'm']

# %%
s = 'pinning for the fjords'
t = s.split()
print(t[2])
# Out:
# the

# %% [markdown]
# ### Joining Characters in the list of Items

# %%
t = ['pinning', 'for', 'the', 'fjords']
delimeter = ' '
delimeter.join(t)
# Out:
# 'pinning for the fjords'

# %% [markdown]
# ### PARSING LINES

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    line = line.rstrip()
    if not line.startswith('From'): continue
    words = line.split()
    print(words[1])

# %% [markdown]
# ### Objects and Values

# %%
a = 'banana'
b = 'bananda'
a is b
# Out:
# False

# %% [markdown]
# ### Aliasing

# %%
a = [1,2,3]
b = a
b is a
# Out:
# True

# %%
b[0] =17
print(a)
# Out:
# [17, 2, 3]

# %%
def delete_head(t):
    del t[0]

# %%
t1 = [1,2]
t2 = t1.append('#')
print(t1)
# Out:
# [1, 2, '#']

# %%
def loop():
    num = []
    while True:
        inp = input("Enter a numbe r")
        if inp.lower() == "done":
            break
        try:
            number = float(inp)
            num.append(number)
            
        except ValueError:
            print("Enter a Valid number or Float Value")

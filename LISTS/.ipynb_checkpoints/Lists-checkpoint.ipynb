# %% [markdown]
# ### Lists are Mutable
# - Can be changed

# %%
numbers = [1, 23, 45, 67, 18]
numbers[3] = "Badbunny"
print(numbers)
# Out:
# [1, 23, 45, 'Badbunny', 18]

# %%
cheeses = ['Cheeddar', 'Edam', 'Gouda']
print(cheeses[8])

# %% [markdown]
# ### Traversing a List

# %%
cheeses = ['Cheeddar', 'Edam', 'Gouda']
for cheese in cheeses:
    print(cheese)
# Out:
# Cheeddar
# Edam
# Gouda

# %%
numbers = [1,2,3,5,6,7,]
for i  in numbers:
    if i > 2:
        print(i)
# Out:
# 3
# 5
# 6
# 7

# %%
numbers = []
while True:
    inp = input("Enter a Number?")
    if inp.lower() == 'done':
        break
    try:
        number = float(inp)
        numbers.append(number)
    except:
        print("Error value , Enter a valid number")
        continue
    print(number)
# Out:
# Enter a Number? 1
# 1.0
# Enter a Number? 2
# 2.0
# Enter a Number? 45
# 45.0
# Enter a Number? 6
# 6.0
# Enter a Number? 7
# 7.0
# Enter a Number? done

# %%
def get_number_list():
    numbers = [] # 1. Create an empty list
    Final_list = []
    while True:
        inp = input("Enter a Number? ")
        if inp.lower() == "done":
            break
        try:
            number = float(inp)
            numbers.append(number)  # 2. Add the valid number to the list
        except ValueError:
            print("Error value, Enter a valid number")
            continue
    for i in numbers:
        if i > 2:
            Final_list.append(i)
   return numbers, Final_List # 3. Return the full list after the loop breaks

# Example usage:
user_input = get_number_list()
print("User_input:", user_input)
print("Final list:", Final_list)
# Out:
#   File <string>:17
#     return numbers, Final_List # 3. Return the full list after the loop breaks
#                                                                               ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ### Method 1

# %% [markdown]
# ### Exercise:
# 𝐓𝐚𝐬𝐤 𝟑: Write a python function called "𝐨𝐥𝐝_𝐩𝐞𝐨𝐩𝐥𝐞()" , that prompts a user to input a Series of ages and then extracts only the"𝐒𝐞𝐧𝐢𝐨𝐫" entries(those over the age of 50)
#
# 𝐑𝐞𝐪𝐮𝐢𝐫𝐞𝐦𝐞𝐧𝐭𝐬:
# 𝟏. 𝐈𝐧𝐩𝐮𝐭 𝐋𝐨𝐨𝐩:
# - Using a while loop to continuosly prompt the user with "Enter a Number?"
#
# 𝟐. 𝐓𝐞𝐫𝐦𝐢𝐧𝐚𝐭𝐢𝐨𝐧:
# - The Loop must stop immediately if the user types "DONE"(regardless of Capitalization)
#
# 𝟑. 𝐄𝐫𝐫𝐨𝐫 𝐡𝐚𝐧𝐝𝐥𝐢𝐧𝐠:
# - If the user enters text that cannot be converted to a number, print "Enter a Valid number" and continue the loop.
#
# 𝟒. 𝐃𝐚𝐭𝐚 𝐒𝐭𝐨𝐫𝐚𝐠𝐞:
# - Save all valid numerical inputs into a list called "user-input"
# - Create a second list called final_list containing only the numbers from the list that are greater than 50
#
# 𝟓. 𝐎𝐮𝐭𝐩𝐮𝐭:
# - Return and print the original list of all entries and the filtered list of ages.

# %%
def old_people():
    user_input = []
    final_list = []
    while True:
        inp = input("Enter a number?")
        """ Capture users inputs/Numbers until a user types DONE"""
        if inp.upper() == 'DONE':
            break
        try:
            number = float(inp)
            user_input.append(number)
        except ValueError:
            print("Enter a valid number")
            continue
    for age in user_input:
        if age > 50:
            final_list.append(age)
    return user_input, final_list
user_input, final_list = old_people()
print("UserInput:", user_input)
print("Old_people", final_list)
# Out:
# Enter a number? 12
# Enter a number? 5
# Enter a number? 78
# Enter a number? 45
# Enter a number? 67
# Enter a number? 23
# Enter a number? DONE
# UserInput: [12.0, 5.0, 78.0, 45.0, 67.0, 23.0]
# Old_people [78.0, 67.0]

# %%
def extract_users_from_csv(path: str) -> list[dict]:
    ...

# %% [markdown]
# ### Deleting Elements

# %%
t = ['a', 'b', 'c']
x = t.pop(1)
print(t)
# Out:
# ['a', 'c']

# %% [markdown]
# ### Lists and Functions

# %%
nums = [3, 41, 12 , 9, 74, 15]
print(len(nums))
# Out:
# 6

# %%
print (sum(nums))
# Out:
# 154

# %% [markdown]
#
# - DEclaring a list and calculating total using sum, count using len, and finally average

# %%
user_input = list()
while True:
    inp = input("Enter a value?")
    if inp.lower() == "done":
        break
    try:
        number = float(inp)
        user_input.append(number)
    except ValueError:
        print("Please Enter a valid number")
    total = sum(user_input)
    count = len(user_input)
average = total / count
print(user_input, total, count, average)
# Out:
# Enter a value? 34
# Enter a value? 6
# Enter a value? 7
# Enter a value? 89
# Enter a value? 23
# Enter a value? done
# [34.0, 6.0, 7.0, 89.0, 23.0] 159.0 5 31.8

# %% [markdown]
# ### Lists and Strings

# %%
s = 'spam'
t = list(s)
print(t)
# Out:
# ['s', 'p', 'a', 'm']

# %%
s = 'pinning for the fjords'
t = s.split()
print(t)
print(t[3])
# Out:
# ['pinning', 'for', 'the', 'fjords']
# fjords

# %% [markdown]
# ### Parsing lines

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    line = line.rstrip()
    if not line.startswith('From '): continue
    words = line.split()
    print(words[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    line = line.rstrip()
    if not line.startswith('From '): continue
    words = line.split()
    print(words[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
a = [1,2,3]
b = [1,2,3]
print(a is b)
print(a==b)
# Out:
# False
# True

# %% [markdown]
# - Different Memory locations yields False , Yet == checks wether items in the list are the same

# %% [markdown]
# ### List arguments

# %%
t = [1,2,3,4,5]
def  delete_head(k):
    k.pop(3)
    return k
print(delete_head(t))
# Out:
# [1, 2, 3, 5]

# %%
t1 = [1,2]
t2 = t1.append(3)
print(t1)
print(t2)
# Out:
# [1, 2, 3]
# None

# %%
t3 = t1 + [3] + [5]
print(t3)
# Out:
# [1, 2, 3, 3, 5]

# %%
def tail(t):
    return t[1:]

# %%
def bad_delete_head(t):
    t = t[1:]

# %%
letters = ['a', 'b', 'c', 'e', 'f']
rest = tail(letters)
print(rest)
# Out:
# ['b', 'c', 'e', 'f']

# %% [markdown]
# ### Exercise 1:
# -  Write a function called **chop** that takes a list and modifies it, removing the first and last elements, and returns **None**. Then write a function called **middle** that takes a list and returns a new list that contains all but the first and last elements.

# %%
#Solution1 
def chop():
    num = []
    while True:
        inp = input("Enter a number")
        if inp.lower() == "done":
            break
        try:
            number = float(inp)
            num.append(number)
        except ValueError:
            print("Enter a Valid number or Float Value")
    del num[-1]
    del num[0]
    user_input = None
    return num, user_input
num, user_input = chop()
print(num)
print(user_input)
# Out:
# Enter a number 1
# Enter a number 2
# Enter a number 3
# Enter a number 4
# Enter a number done
# [2.0, 3.0]
# None

# %%
#solution2 
def chop():
    num = []
    while True:
        inp = input("Enter a number")
        if inp.lower() == "done":
            break
        try:
            number = float(inp)
            num.append(number)
        except ValueError:
            print("Enter a Valid number or Float Value")
    del num[-1]
    del num[0]
    return num
num = chop()
print("Final_list:",num)
# Out:
# Enter a number 12
# Enter a number 3
# Enter a number 56
# Enter a number 4
# Enter a number done
# Final_list: [3.0, 56.0]

# %% [markdown]
#  - Write a function that filers user inputs and returnd aonly those above the age of 50 years

# %%
def old_people():
    user_input = []
    final_list = []
    while True:
        inp = input("Enter a number?")
        """ Capture users inputs/Numbers until a user types DONE"""
        if inp.upper() == 'DONE':
            break
        try:
            number = float(inp)
            user_input.append(number)
        except ValueError:
            print("Enter a valid number")
            continue
    for age in user_input:
        if age > 50:
            final_list.append(age)
    return user_input, final_list
user_input, final_list = old_people()
print("UserInput:", user_input)
print("Old_people", final_list)
# Out:
# Enter a number? 3
# Enter a number? 5
# Enter a number? 6
# Enter a number? 34
# Enter a number? 56
# Enter a number? 7
# Enter a number? DONE
# UserInput: [3.0, 5.0, 6.0, 34.0, 56.0, 7.0]
# Old_people [56.0]

# %% [markdown]
# ### DEBUGGING

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    words = line.split()
    if words[0] != 'From'  : continue
    print(words[2])
# Out:
# Sat
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 fhand = open('mbox-short.txt')
#       2 for line in fhand:
#       3     words = line.split()
# ----> 4     if words[0] != 'From'  : continue
#       5     print(words[2])
#
# IndexError: list index out of range

# %%
for line in fhand:
    words = line.split()
    print('Debug:', words)
    if words[0] != 'From' : continue
    print(words[2])
# Out:
# Debug: ['Details:', 'http://source.sakaiproject.org/viewsvn/?view=rev&rev=39772']
# Debug: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 4
#       1 for line in fhand:
#       2     words = line.split()
#       3     print('Debug:', words)
# ----> 4     if words[0] != 'From' : continue
#       5     print(words[2])
#
# IndexError: list index out of range

# %%
for line in fhand:
    words = line.split()
    print('Debug:',words)
    if words[0] != 'From' : continue
    print(words[2])
# Out:
# Debug: ['Author:', 'stephen.marquard@uct.ac.za']
# Debug: ['Date:', '2008-01-05', '09:12:07', '-0500', '(Sat,', '05', 'Jan', '2008)']
# Debug: ['New', 'Revision:', '39772']
# Debug: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 4
#       1 for line in fhand:
#       2     words = line.split()
#       3     print('Debug:',words)
# ----> 4     if words[0] != 'From' : continue
#       5     print(words[2])
#
# IndexError: list index out of range

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    words = line.split()
    if len(words) == 0: continue
    if words[0] != 'From': continue
    print(words[2])

# %%
fhand = open('mbox-short.txt')
count = 0
for line in fhand:
    words = line.split()
    # print('Debug:', words)
    if len(words) == 0 : continue
    if words[0] != 'From' : continue
    print(words[2])

# %% [markdown]
# ### Excercise 3:
# Rewrite the guardian code in the above example without two if statements. Instead, use a compound logical expression using the or logical operator with a single if statement.

# %%
fhand = open('mbox-short.txt')
count = 0
for line in fhand:
    words = line.split()
    # print('Debug:', words)
    if len(words) == 0  or words[0] != 'From': continue
    print(words[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %% [markdown]
# ### Execise 4:
# - Find all Unique words in the  file
# - Shakespeare used over 20,000 words in his works. But how would you determine that? How would you produce the list of all the words that Shakespeare used? Would you download all his work, read it and track all unique words by hand?
#
# Let’s use Python to achieve that instead. List all unique words, sorted in alphabetical order, that are stored in a file romeo.txt containing a subset of Shakespeare’s work.
#
# To get started, download a copy of the file www.py4e.com/code3/romeo.txt. Create a list of unique words, which will contain the final result. Write a program to open the file romeo.txt and read it line by line. For each line, split the line into a list of words using the split function. For each word, check to see if the word is already in the list of unique words. If the word is not in the list of unique words, add it to the list. When the program completes, sort and print the list of unique words in alphabetical order.

# %%
unique = []
fhand = open('romeo.txt')
for line in fhand:
    words = line.split()
    for word in words:
        if word not in unique:
            unique.append(word)
unique.sort()
print(unique)
# Out:
# ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']

# %% [markdown]
# - sort() sorts the values in the list in alphabetical

# %% [markdown]
# ### Exercise 5
# - MBOX (mail box) is a popular file format to store and share a collection of emails. This was used by early email servers and desktop apps. Without getting into too many details, MBOX is a text file, which stores emails consecutively. Emails are separated by a special line which starts with From (notice the space). Importantly, lines starting with From: (notice the colon) describes the email itself and does not act as a separator. Imagine you wrote a minimalist email app, that lists the email of the senders in the user’s Inbox and counts the number of emails.
#
# Write a program to read through the mail box data and when you find a line that starts with “From”, you will split the line into words using the split function. We are interested in who sent the message, which is the second word on the From line.

# %%
fhand = open('mbox-short.txt')
for line in fhand:
    if line.startswith('From'):
        words = line.split()
        print(words[1])
# Out:
# stephen.marquard@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# zqian@umich.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ...

# %% [markdown]
# ### Exercise 6
# - Rewrite the program that prompts the user for a list of numbers and prints out the maximum and minimum of the numbers at the end when the user enters “done”. Write the program to store the numbers the user enters in a list and use the max() and min() functions to compute the maximum and minimum numbers after the loop completes.

# %%
def numbers():
    user_input =[]
    while True:
        inp = input("Enter a Number of your choice")
        if inp.lower() == 'done':
            break
        try:
            number = float(inp)
            user_input.append(number)
        except ValueError:
            print("Enter a Numeric Value")
        maximum_number = max(user_input)
        minimum_number = min(user_input)
    return maximum_number, minimum_number, user_input
maximum_number, minimum_number, user_input = numbers()
print("User_Input:", user_input)
print("Max_Number:", maximum_number)
print("Min_number:", minimum_number)
# Out:
# Enter a Number of your choice 2
# Enter a Number of your choice 3
# Enter a Number of your choice 5
# Enter a Number of your choice 6
# Enter a Number of your choice done
# User_Input: [2.0, 3.0, 5.0, 6.0]
# Max_Number: 6.0
# Min_number: 2.0

# %% [markdown]
# ### Exercise 7
# 8.5 Open the file mbox-short.txt and read it line by line. When you find a line that starts with 'From ' like the following line:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# You will parse the From line using split() and print out the second word in the line (i.e. the entire address of the person who sent the message). Then print out a count at the end.
# Hint: make sure not to include the lines that start with 'From:'. Also look at the last line of the sample output to see how to print the count.
#
# You can download the sample data at http://www.py4e.com/code3/mbox-short.txt

# %%
def email():
    count = 0 
    while True:
        try:
            fname = input("Enter a file name")
            fhand = open(fname)
            break
        except FileNotFoundError:
            print("Please enter a correct file")
    fhand = open('mbox-short.txt')
    for line in fhand:
        if line.startswith("From:"):
            continue
        elif line.startswith('From'):
            words = line.split()
            count += 1 
            print(words[1])
    print("There were", count, "lines in the file with From as the first word")
    return words, count
words, count = email()
# Out:
# Enter a file name mbox-short.txt
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# There were 27 lines in the file with From as the first word

# %% [markdown]
# ### Exercise 8
# 8.4 Open the file romeo.txt and read it line by line. For each line, split the line into a list of words using the split() method. The program should build a list of words. For each word on each line check to see if the word is already in the list and if not append it to the list. When the program completes, sort and print the resulting words in python sort() order as shown in the desired output.
# You can download the sample data at http://www.py4e.com/code3/romeo.txt

# %%
def unique1():
    unique = []
    while True:
        try:
            fname = input("Enter file name: ")
            fname = open(fname)
        except:
            print("Please enter a correct file path")
            continue
        for line in fname:
            words = line.split()
            for word in words:
                if word not in unique:
                    unique.append(word)
        unique.sort()
        return unique
unique = unique1()
print(unique)
# Out:
# Enter file name:  romeo.txt
# ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']

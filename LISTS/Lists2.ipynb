# %%
def middle():
    z = [1,24,5,'bash', 'conrad', 45]
    special =[]
    first_item = z[0]
    special.append(first_item)
    last_item = z[-1]
    special.append(last_item)
return special
middle() = special, z
print("result2:", special)
print("Modifieslist:", z)
# Out:
#   Cell In[11], line 9
#     middle() = special, z
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
def middle():
    z = [1,24,5,'bash', 'conrad', 45]
    last_terms = []
    while True:
        first_item = z[0]
        last_terms.append(first_item)
        last_item = z[-1]
        last_terms.append(last_item)
    
    return last_terms, z
last_terms, z = middle()
print(last_terms, z)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       7         last_item = z[-1]
#       8         last_terms.append(last_item)
#       9
#      10     return last_terms, z
# ---> 11 last_terms, z = middle()
#      12 print(last_terms, z)
#      13
#
# Cell In[9], line 8, in middle()
#       4     while True:
#       5         first_item = z[0]
#       6         last_terms.append(first_item)
#       7         last_item = z[-1]
# ----> 8         last_terms.append(last_item)
#       9
#      10     return last_terms, z
#
# KeyboardInterrupt:

# %%
t = [1, 24, 5, 'bash', 'Connrad', 45, 86]

def chop(k):
    if len(k) >= 2:
        del k[0]   # Removes the first element
        del k[-1]  # Removes the last element
    elif len(k) == 1:
        del k[0]   # Empties the list if it only has one item
    # Returns None automatically

# Test the function
result = chop(t)

print("Function returned:", result)  # Output: None
print("Modified list:", t)           # Output: [24, 5, 'bash', 'Connrad', 45]
# Out:
# Function returned: None
# Modified list: [24, 5, 'bash', 'Connrad', 45]

# %%
def email():
    count = 0
    fhand = open('mbox-short.txt')
    for line in fhand:
        if line.startswith('From:'):
            continue 
        elif line.startswith('From'):
            words = line.split()
            count += 1
            print(words[1])
    print("There were", count, "lines in the file with From as the first word")
    return words, count
words , count = email()
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# There were 27 lines in the file with From as the first word

# %%
def email():
    count = 0 
    while True:
        try:
            fname = input("Enter a file name")
            fhand = open(fname)
            break
        except FileNotFoundError:
            print("Please enter a correct file")
    fhand = open('mbox-short.txt')
    for line in fhand:
        if line.startswith("From:"):
            continue
        elif line.startswith('From'):
            words = line.split()
            count += 1 
            print(words[1])
    print("There were", count, "lines in the file with From as the first word")
    return words, count
words, count = email()
# Out:
# Enter a file name mbox-short.txt
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# There were 27 lines in the file with From as the first word

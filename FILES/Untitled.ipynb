# %%
fname = input('Enter a file name')
try:
    fhand = fname.read()
except:
    print('Could nort open the file')
count = 0
for line in fhand:
    if line.startswith("Subject:"):
        count += 1
print("Number of lines:", count)
# Out:
# Enter a file name mbox-short.txt
# Could nort open the file
# Number of lines: 0

# %%
fname = input('Enter a file name')
try:
    fhand = fname.read()
except:
    print('Could not open the file')
print("Number of lines:", len(fhand))
# Out:
# Enter a file name mbox-short.txt
#   Cell In[11], line 6
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
fname = input("Enter a file Name")
fhand = open(fname)
fhand2 = fhand.read()
print(len(fhand2))
# Out:
# Enter a file Name mbox-short.txt
# 94626

# %%
fname = input("Enter a file name ")
fhand = fname.open()
data = fhand.read()
print(len(data))

# %%
fname = input("Enter a file name")
try:
    content = open(fname)
except:
    print("Couldnt open the file")
data = content.read()
print(len(data))
# Out:
# Enter a file name mbox-short.txt
# 94626

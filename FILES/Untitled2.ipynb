# %%
def domain():
    while True:
        try:
            file_name = open("mbox-short.txt")
            break
        except FileNotFoundError:
            print(f"File not found, {file_mame}")
    domain_counts = {}
    for line in file_name:
        if not line.startswith("From "):
            continue
        words = line.split()
        if len(words) < 2:
            continue
        email = words [1]
        email_parts = email.split('@')
        if len(email_parts) < 2:
            continue
        domain = email_parts[1]
        domain_counts[domain] = domain_counts.get(domain, 0) + 1 
print("Domain", domain_counts)
    # return domain_counts
# domain_counts = domain()
#print("Domain", domain_counts)
if __name__ == " __main__ ":
    domain()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 22
#      18         if len(email_parts) < 2:
#      19             continue
#      20         domain = email_parts[1]
#      21         domain_counts[domain] = domain_counts.get(domain, 0) + 1
# ---> 22 print("Domain", domain_counts)
#      23     # return domain_counts
#      24 # domain_counts = domain()
#      25 #print("Domain", domain_counts)
#
# NameError: name 'domain_counts' is not defined

# %%
file_name = open("mbox-short.txt")
email_owner = {}
for line in file_name:
    if line.startswith("From "):
        words = line.split()
        emails = words[1]
        email_owner[emails] = email_owner.get(emails,0) +1 
        max_emails = None
        max_count = None
        for email, count in email_owner.items():
            if max_count is None or count > max_count:
                max_emails = email
                max_count = count            
print(max_emails, max_count)
# Out:
# cwen@iupui.edu 5

# %%
file_name = open("mbox-short.txt")
email_owner = {}
for line in file_name:
    if line.startswith("From "):
        words = line.split()

# %%
#Most Prolific Commiter
def email_counts():
    while True:
        try:
            file_name = open(input("Enter a file Name"))
            break
        except FileNotFoundError:
            print("Cant open File")
    email_owner = {}
    for line in file_name:
        #Sanity check 
        if not line.startswith("From "):
            continue
        words = line.split()
        emails = words[1]
        email_owner[emails] = email_owner.get(emails, 0) + 1 
        max_emails = None 
        max_count = None
        for email, count in email_owner.items():
            if max_count is None or count > max_count:
                max_emails = email 
                max_count = count
    return email_owner, max_emails, max_count
email_owner, max_emails, max_count = email_counts()
print(max_emails, max_count)
if __name__ == " __main__ ":
    email_counts()
# Out:
# Enter a file Name mbox-short.txt
# cwen@iupui.edu 5

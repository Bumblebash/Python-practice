# %% [markdown]
# ## FUNCTIONS
#  - Function Calls

# %% [markdown]
# - Functions is a named sequesnce of statements that perfomrs a computation.

# %%
type(32)
# Out:
# int

# %%
max('Hello world')
# Out:
# 'w'

# %%
min('Hello world')
# Out:
# ' '

# %%
len('Hello world')
# Out:
# 11

# %%
str(32)
# Out:
# '32'

# %% [markdown]
# - Math Library
#    - a built-in standard module that provides access to a comprehensive collection of common mathematical functions and constants

# %%
import math

# %%
degrees = 45
radians = degrees / 360.0 * 2 * math.pi
math.sin(radians)
# Out:
# 0.7071067811865476

# %% [markdown]
# ### FOR LOOP

# %% [markdown]
# ### RANDOM NUMBERS

# %%
import random
for i in range(10):
    x = random.random()
    print(x)
# Out:
# 0.7626664979744939
# 0.5150594749147077
# 0.1673942472885308
# 0.6540848076514311
# 0.3963084260438269
# 0.9199607612292999
# 0.23349360049119594
# 0.585587335222698
# 0.9281180872131162
# 0.6603255379553052

# %%
random.randint(5,10)
random.randint(5,10)
# Out:
# 8

# %% [markdown]
# ### Adding New Functions
#  - A function definition specifies the name of a new function and the sequence of statements that execute when the function is called.

# %%
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")

# %% [markdown]
# - def is a keyword that indicates that this is a function definition. The name of the function is print_lyrics.
# - function definiton ; def print_lyrics():

# %% [markdown]
# - Exercise 1:
# - - Exercise 2
# - Move the last line of this program to the top, so the function call appears before the definitions. Run the program and see what error message you get.

# %%
repeat_lyrics()
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")

def repeat_lyrics():
    print_lyrics()
    print_lyrics()
# Out:
#   Cell In[23], line 2
#     print("I'm a lumberjack, and I'm okay.")
#     ^
# IndentationError: unexpected indent

# %%
def print_balers():
    print("I love DataEngineering")
    print("I love Data Anlaytics")
def repeat_ballers():
    print_balers()
    print_balers()
print_balers()
# Out:
# I love DataEngineering
# I love Data Anlaytics

# %% [markdown]
# - Exercise 3: Move the function call back to the bottom and move the definition of print_lyrics after the definition of repeat_lyrics. What happens when you run this program?

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print("I sleep all night and I work all day.")
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# - NOTE: Functions must be  defined before they are called.

# %% [markdown]
# ### Parameters & Arguments

# %%
def print_twice(bruce):
    print(bruce)
    print(bruce)
print_twice('spam ' * 4)
# Out:
# spam spam spam spam
# spam spam spam spam

# %% [raw]
# print_twice('Spam' )

# %%
def print_twice(bruce):
    print(bruce)
    print(bruce)
michael = 'Eric, the half bee.'
print_twice(michael)
# Out:
# Eric, the half bee.
# Eric, the half bee.

# %%
def addtwo(a, b):
    added = a + b
    return added 
x = addtwo(3,5)
print(x)
# Out:
# 8

# %%
def subtwo(x, y):
    sub = x - y
    return sub
z = subtwo(8,9)
print(z)
# Out:
# -1

# %% [markdown]
# ### Uses of Functions

# %% [markdown]
# - Creating a new function gives you an opportunity to name a group of statements, which makes your program easier to read, understand, and debug
# - Functions can make a program smaller by eliminating repetitive code. Later, if you make a change, you only have to make it in one place.
# - Dividing a long program into functions allows you to debug the parts one at a time and then assemble them into a working whole.
# - Well-designed functions are often useful for many programs. Once you write and debug one, you can reuse it.

# %% [markdown]
# ### Exercise 2:
# - What is the purpose of the "def" keyword in Python?
# - a) It is slang that means “the following code is really cool”
# - b) It indicates the start of a function
# - c) It indicates that the following indented section of code is to be stored for later
# - d) b and c are both true
# - e) None of the above
#
# == The answer is b and c

# %% [markdown]
# ### Exercise 5:
# What will the following Python program print out?

# %%
def fred():
    print("Zap")
def jane():
    print("ABC")
jane()
fred()
jane()
# Out:
# ABC
# Zap
# ABC

# %% [markdown]
#  ## Exercise 6:
# - Rewrite your pay computation with time-and-a-half for overtime and create a function called computepay which takes two parameters (hours and rate).

# %%
def computepay(hours, Rate):
      if hours <= 40:
            pay = Rate * hours
      else:
           regular_pay = 40 * Rate
           overtime = hours - 40 
           overtime_pay = overtime * Rate * 1.5
           pay = regular_pay + overtime_pay
      return pay
try:
    hours = float(input("Enter hours: "))
    Rate = float(input("Enter Rate: "))
    print('Pay:', computepay(hours, Rate))
except:
    print("Error: Enter Numeric Characters")
# Out:
# Enter hours:  45
# Enter Rate:  10
# Pay: 475.0

# %% [markdown]
# ### NOTE:
# - ##### Error handling:
#    - should wrap around risky operations (like user input or file reading).
#   - That way, if you later reuse grade(score) in another program (say, reading scores from a file), you don’t drag along unnecessary try/except blocks — the function just does its job.

# %% [markdown]
# ### Exercise 7:
# - Write a program to prompt for a score between 0.0 and 1.0. If the score is out of range, print an error message. If the score is between 0.0 and 1.0, print a grade using the following table:
#  - Score   Grade
# - >= 0.9     A
# - >= 0.8     B
# - >= 0.7     C
# - >= 0.6     D
# -  < 0.6     F

# %%
def grade(score):

        if score < 0 or score > 1:
            return("Score Out of range")
        elif score >= 0.9:
            grade = "A"
        elif score >= 0.8:
            grade = "B"
        elif score >= 0.7:
            grade = "C"
        elif score >= 0.6:
            grade = "D"
        else:
            grade = "F"
        return grade
try:
    score = float(input("Enter a score:"))
    print("Grade:", grade(score))
except:
     print("Error: Non-Numeric input")
# Out:
# Enter a score: 0.689
# Grade: D

# %% [markdown]
# ### Glossary

# %% [markdown]
# 1) algorithm
#  - A general process for solving a category of problems.
# 2)  Argument/paramter
#    - A value provided to a function when the function is called. This value is assigned to the corresponding parameter in the function.
#    - (score)
# 3) Body
# - Sequence of statements inside a function definition
# 4)  Flow execution
#   - The order in which statements are executed during a program run.
# 5) Function
# - A named sequence of statements that performs some useful operation. Functions may or may not take arguments and may or may not produce a result.
# 6) Function Call
#   - A statement that executes a function. It consists of the function name followed by an argument list.
#   - def grade(score)

# %%
def func(x):
    print(x)
func(10)
func(20)
# Out:
# 10
# 20

# %%
def greet(lang):
    if lang == 'es':
        return 'Hola'
    elif lang == 'fr':
        return 'Bonjour'
    else:
        return 'Hello'
print(greet('fr'), 'Micheal')
# Out:
# Bonjour Micheal

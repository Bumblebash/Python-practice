# %%
17 and True
# Out:
# True

# %% [markdown]
# ## CONDITIONAL EXECUTION

# %%
x = 23
if x > 0:
    print('x is positive')
# Out:
# x is positive

# %%
 y = 9
 x = 3
 if x > y:
     print(x)
     print(y)
 else:
     print('None')
# Out:
# None

# %%
x = 3
if x < 10:
    print('Small')
    print ('Done')
# Out:
# Small
# Done

# %%
y = 49
if y % 5 == 0:
    print('y is even')
else:
    print('y is odd')
# Out:
# y is odd

# %% [markdown]
# ### CHAINED CONDITIONALS

# %%
x = 13 
y =  13 
if x<y:
    print('x less than y')
elif x>y:
    print('x is greater than y')
else:
    print('x are y are equal')
# Out:
# x are y are equal

# %%
choice = 'a'
if choice == 'a':
    print('Bad guess')
elif choice  == 'b':
    print('Good guess')
elif choice == 'c':
    print('Close, but not correct')
# Out:
# Bad guess

# %% [markdown]
# ## Nested Conditionals
# - Conditional containg multiple branches

# %%
x =4
y =9
if x == y:
    print('x and y are equal')
elif x<y :
        print('x is less than y')
else:
        print('x is greater than y')
# Out:
# x is less than y

# %%
# Nested Conditional
x = 19
y =19
if x== y:
    print('X and Y are equal')
else:
    if x<y:
        print('x is less than y')
    else:
        if x>y:
            print('x is gretaer than y')
# Out:
# X and Y are equal

# %% [markdown]
# ### Catching exceptions using try and except
# - For error handling and robust structure(To protect programs from crushing after wrong inputs)

# %%
prompt = "What is the air of the unladed air velocity of an uladen swallow?\n"
speed = input(prompt)
# Out:
# What is the air of the unladed air velocity of an uladen swallow?
#  23

# %%
int(speed)
# Out:
# 23

# %%
# Simple Program to Convert Farenheight Temperature to Celisius Tempreature

# %%
#Method 1
far = float(input('Enter Farenheight Temeprature:\n'))
cel = (far - 32) * 5/9
print(cel, "C")
# Out:
# Enter Farenheight Temeprature:
#  45
# 7.222222222222222 C

# %%
#Method2
inp = input('Enter Fahrenheit Temperature: ')
fahr = float(inp)
cel = (fahr - 32.0) * 5.0 / 9.0
print(cel)

# %% [markdown]
# ### Try and except
# - 12/2/2026

# %%
inp = input('Enter Fahrenheight Tempetrature:')
try:
    fahr = float(inp)
    cel = (fahr -32.0) * 5.0 / 9.0
    print(cel)
except:
    print('please enter  a number')
# Out:
# Enter Fahrenheight Tempetrature: 19
# -7.222222222222222

# %%
#Method2
try: 
    Fahr  = float(input("Enter Farenheight Temp: \n"))
    cel = (Fahr - 32.0) * 5.0 /9.0
    print(cel, "C")
except:
    print('Enter a number')
# Out:
# Enter Farenheight Temp:
#  19
# -7.222222222222222 C

# %% [markdown]
# ### - Exercise
# 1.  Rewrite a robust your pay computation to give the employee 1.5 times the hourly rate for hours worked above 40 hours.
# 2.  Exercise 2: Rewrite your pay program using try and except so that your program handles non-numeric input gracefully by printing a message and exiting the program. The following shows two executions of the program:

# %%
try:
    hour = float(input("Enter Hours: \n"))
    rate = float(input("Enter Rate: \n"))
    
    if hour <= 40:
        pay = hour * rate
    else:
        regular_pay =  40 * rate
        over_time = hour - 40
        over_time_pay = rate * 1.5 * over_time
        pay = over_time_pay + regular_pay
    print("pay: USD",pay)
except:
    print("Enter a numeric input")
# Out:
# Enter Hours:
#  45
# Enter Rate:
#  10
# pay: USD 475.0

# %% [markdown]
# - Exercise 2:
# - Write a program to prompt for a score between 0.0 and 1.0. If the score is out of range, print an error message. If the score is between 0.0 and 1.0, print a grade using the following table
#
#    Score   Grade
# >= 0.9     A
# >= 0.8     B
# >= 0.7     C
# >= 0.6     D
#  < 0.6     F

# %%
try:
    score = float(input("Enter a score: \n"))
    if score < 0.0 or score > 1.0:
        print("Score out of range")
    else:
        if score >= 0.9:
             Grade = "A"
        elif score>= 0.8:
            Grade ="B"
        elif score >= 0.7:
            Grade = "C"
        elif score >= 0.6:
            Grade = "D"
        else:
            Grade = F
        print("Grade:", Grade)
except:
    print("Error:Non Numeric Input")
# Out:
# Enter a score:
#  boy
# Error:Non Numeric Input

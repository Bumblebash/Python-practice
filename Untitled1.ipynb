# %%
content = open('FILES/mbox-short.txt')
count = 0
for file in content:
    count += 1
print('count:', count)
# Out:
# count: 1910

# %%
content = open ('FILES/mbox-short.txt')
for file in content:
    print(content)

# %%
content = open('FILES/mbox-short.txt')
for line in content:
    print(line)

# %%
content = open('FILES/mbox-short.txt')
inpt = content.read()
print(len(inpt))
# Out:
# 94626

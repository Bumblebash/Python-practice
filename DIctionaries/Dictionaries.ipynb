# %%
eng2sp = {'one': 'uno', 2, 'keith': 'dos', 'george': 3}
print(eng2sp['keith'])
# Out:
#   Cell In[2], line 1
#     eng2sp = {'one': 'uno', 2, 'keith': 'dos', 'george': 3}
#                             ^
# SyntaxError: ':' expected after dictionary key

# %%
vals = list(eng2sp.values())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vals = list(eng2sp.values())
#
# AttributeError: 'set' object has no attribute 'values'

# %%
eng2sp ={'one': 'uno', 'two': f'R{2500}', 'three':'trees'}
print(eng2sp['one'])
# Out:
# uno

# %%
eng2sp = ['one']
eng2sp = dict()
print(eng2sp)
# Out:
# {}

# %%
vals = list(eng2sp.values())
'uno' is vals
# Out:
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\User\AppData\Local\Temp\ipykernel_15324\96525387.py:2: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   'uno' is vals
# False

# %% [markdown]
# ### Exercise
# - Exercise 1: Download a copy of the file
#
# www.py4e.com/code3/words.txt
#
# Write a program that reads the words in words.txt and stores them as keys in a dictionary. It doesn’t matter what the values are. Then you can use the in operator as a fast way to check whether a string is in the dictionary.

# %%
count = 0
dictionary_words = dict()
fhand = open('words.txt')
for line in fhand:
    words = line.split()
    for word in words:
        count += 1
        if word in dictionary_words:
            continue
        dictionary_words[word] = count
print(count)
# Out:
# 210

# %%
words= []
count = 0 
fhand = open('words.txt')
file = fhand.read()
word  = file.split()
for line in word:
    if line not in words:
        words.append(line)
        count += 1
words.sort()
print(words)
print(count)
# Out:
# ['If', 'Interestingly,', 'Our', 'The', 'This', 'We', 'What', 'Writing', 'You', 'a', 'activity', 'amounts', 'analysis', 'and', 'are', 'as', 'ask', 'assistants', 'assumes', 'be', 'behalf', 'best', 'book', 'boring', 'built', 'can', 'care', 'cell', 'computer', 'computers', 'continuously', 'could', 'creative', 'current-day', 'daily', 'data', 'difficult', 'do', 'else', 'essentially', 'everyone}', 'explain', 'fast', 'figure', 'find', 'for', 'from', 'fun', 'hardware', 'have', 'having', 'helpful', 'helping', 'how', 'humans', 'if', 'in', 'is', 'it', 'kinds', 'knew', 'know', 'language', 'laptops', 'like', 'lives', 'living', 'making', 'many', 'me', 'memory', 'mind-numbing', 'needs', 'newfound', 'next', 'of', 'often', 'on', 'once', 'only', 'or', 'our', 'out', 'personal', 'phones', 'problem', 'program', 'program,', 'programming', 'programs', 'question', 'ranging', 'reasons', 'reptitive', 'rewarding', 'skills', 'solve', 'solving', 'someone', 'speak', 'surrounded', 'take', 'tasks', 'tell', 'that', '
# ...

# %%
fhand = open('words.txt')
file = fhand.read()
print(file)

# %%
file = []
fhand = open('words.txt')
file = fhand.read()
# word = file.split()
for line in file:
    if line.startswith('{}'):
        print(line)

# %%
fname = input('Enter the file name:')
try:
    fhand = open(fname)
except FileNotFoundError:
    print('File Not Found:', fname)
    exit()

counts = dict()
for line in fhand:
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1
print(counts)
# Out:
# Enter the file name: words.txt
# ...

# %% [markdown]
# ### Looping and Dictionaries

# %%
counts = {'chuck': 1, 'annie': 42, 'jan': 100}
for key in counts:
    if counts[key] > 10:
        print(key, counts[key])
# Out:
# annie 42
# jan 100

# %%
counts = {'chuck': 1, 'annie': 42, 'jan': 100}
lst = list(counts.keys())
print (lst)
lst.sort()
print(lst)
for key in lst:
    print(key, counts[key])
# Out:
# ['chuck', 'annie', 'jan']
# ['annie', 'chuck', 'jan']
# annie 42
# chuck 1
# jan 100

# %% [markdown]
# ### Advanced text Parsing

# %%
import string
dname = input('Enter the file Name:')
try:
    fhand = open(fname)
except:
    print('File cannet be opened:', fname)
    exit()
counts = dict()
for line in fhand:
    line = line.rstrip()
    #First two parameters are empty strings
    line = line.translate(line.maketrans("", "", string.punctuation))
    line = line.lower()
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1
print(counts)
# Out:
# Enter the file Name: words.txt
# ...

# %% [markdown]
# ### Debugging

# %% [markdown]
# - Done to perform Sanity Checks and Consistency Checks

# %% [markdown]
# ### Exercises 1
# - Write a program that categorizes each mail message by which day of the week the commit was done. To do this look for lines that start with “From”, then look for the third word and keep a running count of each of the days of the week. At the end of the program print out the contents of your dictionary (order does not matter).

# %%
def emails():
    results = []
    while True:
        try:
            inp = input("Enter a File")
            fhand= open(inp)
            break
        except FileNotFoundError:
            print("File Not Found")
    for line in fhand:
        if line.startswith("From "):
            print(line)
    return line 
line = emails()
print("Line:", line)
# Out:
# Enter a File mbox-short.txt
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
#
# From zqian@umich.edu Fri Jan  4 10:17:43 2008
#
# From antranig@caret.cam.ac.uk Fri Jan  4 10:04:14 2008
#
# From gopal.ramasammycook@gmail.com Fri Jan  4 09:05:31 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
#
# ...

# %%
inp = 'mbox-short.txt'
fhand = open(inp)
for line in fhand:
    if line.startswith("From "):
        print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
#
# From zqian@umich.edu Fri Jan  4 10:17:43 2008
#
# From antranig@caret.cam.ac.uk Fri Jan  4 10:04:14 2008
#
# From gopal.ramasammycook@gmail.com Fri Jan  4 09:05:31 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
#
# ...

# %%
def emails():
    while True:
        try:
            inp = input("Enter a File: ")
            fhand = open(inp)
            break
        except FileNotFoundError:
            print("File Not Found")

    for line in fhand:
        if line.startswith("From "):
            print(line)

emails()
# Out:
# Enter a File:  mbox-short.txt
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
#
# From zqian@umich.edu Fri Jan  4 10:17:43 2008
#
# From antranig@caret.cam.ac.uk Fri Jan  4 10:04:14 2008
#
# From gopal.ramasammycook@gmail.com Fri Jan  4 09:05:31 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
#
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
#
# ...

# %% [markdown]
# ### Exercise 2:
# - Write a program that categorizes each mail message by which day of the week the commit was done. To do this look for lines that start with “From”, then look for the third word and keep a running count of each of the days of the week. At the end of the program print out the contents of your dictionary (order does not matter).
#
# - Sample Line:
# - From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# - python dow.py
# - Enter a file name: mbox-short.txt
# - {'Fri': 20, 'Thu': 6, 'Sat': 1}

# %%
filename = 'mbox-short.txt'
try:
    fhand = open(filename)
except FileNotFoundError:
    print("Could Not Open File")
    quit()

#Initialize the dictionary  to hold dat counts
day_counts = dict()

#Process each line in the file
for line in fhand:
    if not line.startswith('From '):
        continue

    # Split the line into words
    words = line.split()

    #Check if the line has enough words to avoid IndexError
    if len(words) < 3:
        continue
    day = words[2]


    day_counts[day] = day_cwords ounts.get(day, 0) + 1

print(day_counts)
# Out:
# {'Sat': 1, 'Fri': 20, 'Thu': 6}

# %% [markdown]
# Exercise 3: Write a program to read through a mail log, build a histogram using a dictionary to count how many messages have come from each email address, and print the dictionary.

# %%
file = ('mbox-short.txt')
fhand = open(file)
email_counts = {}
for line in fhand:
    if not line.startswith("From "):
        continue
    words = line.split()

    #Safety check
    if len(words) < 2:
        continue
    email = words[1]

    email_counts[email] = email_counts.get(email, 0) + 1
print(email_counts)
# Out:
# {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2, 'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1, 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}

# %% [markdown]
# # Loops & Interations

# %% [markdown]
# - We look at how Python repeats statements using Looping Structures

# %%
#Repeated Steps
n = 5
while n > 0:
    print(n)
    n = n - 1
print('Blastoff!')
print(n)
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!
# 0

# %% [markdown]
# - Loops (repeated steps) have iteration variables that change each time through a loop. Often these iteratiion variables go through a sequence of numbers.

# %%
n = 5 
while n > 0:
    print('Lather')
    print('Rinse')
print('Dry off!')

# %% [markdown]
# ### Breaking Out of a Loop

# %%
while True:
    line = input('>')
    if line == 'done' :
        break
    print(line)
print('Done!')
# Out:
# > hello
# hello
# > hello
# hello
# > hey
# hey
# > done
# Done!

# %% [markdown]
# # The While Statement

# %%
n = 7
while n > 0:
    print(n)
    n = n-1 
print('Hello')
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# Hello

# %%
while True:
    line = input('< ')
    if line == 'done':
        break
    print(line)
print('done')
# Out:
# <  acajcv
# acajcv
# <  donee
# donee
# <  donme
# donme
# <  done
# done

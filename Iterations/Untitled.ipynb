# %%
count = 0
total = 0
while True:
    line = input("Enter a Number ")
    if line.lower() == 'Done':
        break 
        
        try:
            number = float(line)
        except:
            print("Invalid Input")
        continue
        count += 1
        total += number
print(count, total)
# Out:
# Enter a Number  21
# Enter a Number  3
# Enter a Number  DOINE
# Enter a Number  DONE
